# %% [markdown]
# # Entendiendo los datos de CCS

# %%
### Librerias

import pandas as pd

# %%
# # Dataframe Fact Ventas

df_fv = pd.read_csv('./data_source/data_query_for_fac_ventas.csv')
df_fv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7701 entries, 0 to 7700
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   NUMERO_DE_IDENTIFICACION  7701 non-null   int64
#  1   PRIMER_APELLIDO           7701 non-null   object
#  2   SEGUNDO_APELLIDO          7566 non-null   object
#  3   PRIMER_NOMBRE             7701 non-null   object
#  4   SEGUNDO_NOMBRE            7328 non-null   object
#  5   PRECIO_NETO               7701 non-null   float64
#  6   FECHA_DE_PAGO             7701 non-null   object
#  7   RENOVACION                7468 non-null   object
#  8   FECHA_DE_VENTA            7701 non-null   object
#  9   PROFESION                 5905 non-null   object
#  10  GENERO                    5802 non-null   object
#  11  FECHA_DE_NACIMIENTO       7698 non-null   object
#  12  CIUDAD_REGION             7527 non-null   object
#  13  MODALIDAD                 7178 non-null   object
#  14  PROCEDENCIA               7205 non-null   object
#  15  MEDIO_DE_PAGO             6912 non-null   object
#  16  RESPONSABLE_VENTA         7637 non-null   object
#  17  elaboro                   7492 non-null   object
# dtypes: float64(1), int64(1), object(16)
# memory usage: 1.1+ MB
